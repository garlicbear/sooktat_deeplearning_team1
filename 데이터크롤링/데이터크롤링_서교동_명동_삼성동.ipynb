# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup
import re
import time
import math

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


#드라이버 불러오기
path = 'chromedriver'
excutable_path = 'chromedriver.exe'
source_url = "https://map.kakao.com/"
driver = webdriver.Chrome(executable_path=excutable_path)

#인터넷 접속
driver.get(source_url)

#서치
search=driver.find_element(By.XPATH,'//*[@id="search.keyword.query"]')
search.send_keys("서교동 카페")
search.send_keys(Keys.ENTER)

driver.implicitly_wait(time_to_wait=5)

# %%
#카페 이름, url 뜯어오기

urls=[]
names=[]


def name_url():
    
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    moreviews = soup.find_all(name="a", attrs={"class":"moreview"}) #상세보기 모두 가져오기. 
    namelist=soup.find_all(name='a',attrs={"class":"link_name"}) #식당 이름 가져오기
    #근데 스크롤 안 내린 거 상에서만 다 가져온 것. 
    # < 눌러서 더 가져와야 함. 
    
    for i in moreviews:
        page_url=i.get("href")
        urls.append(page_url)

    for i in namelist:
        name=i.get("title")
        names.append(name)
    #첫 페이지에서 이름 뜯어옴.

# %%
#첫 페이지에서 가져오기 
name_url()

# %%
#장소 더보기 누르기
more_place_button=driver.find_element(By.XPATH,'//*[@id="info.search.place.more"]')
driver.execute_script("arguments[0].click();", more_place_button)

# %%
page_num=2 #현재 페이지

while True:
    name_url() #현재 페이지에서 다 뜯어오기
    print(page_num)
    page_num+=1 #다음 페이지 번호
    if page_num==6:
        print("> 버튼을 누릅니다.")
        next_button=driver.find_element(By.XPATH,'//*[@id="info.search.page.next"]') #넥스트 버튼 찾기.
        if next_button.get_attribute("class")=='next disabled':
            print("끝났습니다.")
            break
        driver.execute_script("arguments[0].click();", next_button) #넥스트 버튼 누르기
        page_num=1  #페이지 번호 초기화
        print(next_button.get_attribute("class"))
        
    else:
        page_xpath= '//*[@id="info.search.page.no'+str(page_num)+'"]' #다음 페이지의 xpath
        page_button=driver.find_element(By.XPATH,page_xpath) #다음 페이지 버튼 찾기
        driver.execute_script("arguments[0].click();", page_button)  #다음 페이지 버튼 누르기
# Out:
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next disabled
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# 끝났습니다.

# %%
names
# Out:
# ['피오니 홍대점',
#  '카페공명',
#  '943킹스크로스',
#  '앤트러사이트 서교점',
#  '테일러커피 서교점',
#  '무신사테라스',
#  '당인리책발전소',
#  '콜린',
#  '톤앤매너',
#  '1984',
#  '땡스네이쳐',
#  '키쉬미뇽',
#  '샌드커피 논탄토',
#  '브런치가',
#  '이미커피',
#  '빌리프커피로스터스',
#  '허밍벨라',
#  '비트포비아 홍대던전점',
#  'W카페',
#  '더페이머스램',
#  '히어로보드게임카페 홍대1호점',
#  '앤디스커피',
#  '카페 지금여기',
#  '서울이스케이프룸 홍대2호점',
#  '노티드 연남',
#  '카페장쌤',
#  '공상온도',
#  'ESC방탈출카페 홍대점',
#  '라헬의부엌 홍대점',
#  '멜로우',
#  '빌리프커피로스터스',
#  '허밍벨라',
#  '비트포비아 홍대던전점',
#  'W카페',
#  '더페이머스램',
#  '히어로보드게임카페 홍대1호점',
#  '앤디스커피',
#  '카페 지금여기',
#  '서울이스케이프룸 홍대2호점',
#  '노티드 연남',
#  '카페장쌤',
#  '공상온도',
#  'ESC방탈출카페 홍대점',
#  '라헬의부엌 홍대점',
#  '멜로우',
#  '커피폴리',
#  '민트하임',
#  '산리오러버스클럽',
#  '미스터리룸이스케이프 홍대2호점',
#  '딥커피',
#  '8810리스트레토바',
#  '히어로보드게임카페 홍대2호점',
#  '딩굴딩굴알타미라',
#  '모파상',
#  '카페 사운드웨이브',
#  '비포블루밍',
#  '미어캣프랜즈',
#  '재미난조각가 홍대점',
#  '카페333',
#  '리플로우 연남점',
#  '카페로제',
#  '애프터눈커피',
#  '싸인이스케이프 홍대점',
#  '카페시루모락',
#  '러빈허플라워&갤러리카페',
#  '모리츠플라츠',
#  '플레이보드 홍대2호점',
#  '금옥당 서교점',
#  '집사의하루 홍대점',
#  '타이거슈가 홍대본점',
#  '모멘트커피',
#  '퀜치커피',
#  '아비아채 서울홍대점',
#  '앤티크커피',
#  '스타벅스 홍대역점',
#  '스타벅스 홍대입구역사거리R점',
#  '모센즈 스위트',
#  '스타벅스 홍대공항철도역점',
#  '알디프',
#  '플랫랜드',
#  '커피랩',
#  '낙랑파라',
#  '델문도',
#  '밀로커피로스터스',
#  '더귀여워',
#  '코코샌드',
#  '쇼콜라윰',
#  '홍대반지카페',
#  '어썸마운틴',
#  '폴링디저트',
#  '비하인드',
#  '스타일난다 핑크풀카페 홍대점',
#  '리얼이스케이프챌린지',
#  '슈아브',
#  '큐브이스케이프 홍대점',
#  '겨울이머무는집',
#  '설빙 홍대입구역점',
#  '반지대학 홍대본점',
#  '카페그랑주',
#  '스핀오프',
#  '토라비',
#  '커피탐이나',
#  '키이스케이프 홍대점',
#  '빌리엔젤 홍대점',
#  '스타벅스 망원역점',
#  '카페모노블럭',
#  '스타벅스 합정메세나몰점',
#  'C27 홍대점',
#  '카페데코믹스 홍대점',
#  '안녕낯선사람',
#  '리밀앤밀리',
#  '메가MGC커피 홍대입구역점',
#  '킥킥나무',
#  '투썸플레이스 홍대입구역점',
#  '더조커',
#  '아날로그가든',
#  '칼디커피',
#  '나인나인',
#  '비밀의화원 미드나잇점',
#  '그로브177',
#  '오바도즈',
#  '브레이크아웃이스케이프 홍대점',
#  '카페꼬모',
#  '이스케이퍼스 2호점',
#  '비트포비아 던전101',
#  '시나모롤 스위트카페',
#  '가비애',
#  '스타벅스 서교동사거리',
#  '할리스 홍대입구역점',
#  '커피짱',
#  '디어라이프카페',
#  '카페소공원',
#  '스타벅스 동교점',
#  'PIT COFFEE',
#  '띵크프룻',
#  '낮인더무드',
#  '아메노히커피점',
#  '포라운지',
#  '쥬마뺄',
#  '휴카페',
#  '놀숲플러스 홍대점',
#  '언플러그드 홍대점',
#  '투썸플레이스 홍대걷고싶은거리점',
#  '커피빈 홍대역점',
#  '로파이',
#  '엑스케이프 홍대점',
#  '커피스미스 홍대점',
#  '구름뜬하늘',
#  '더블하모니',
#  '해피베어데이 합정점',
#  '하품룸카페',
#  '리쏘네',
#  '나와나타샤',
#  '신이도가',
#  '몬스터케이브',
#  '도자기카페줄',
#  '얀쿠브레',
#  'EGO카페',
#  '레드플랜트',
#  '스타벅스 합정폴리스R점',
#  '폴바셋 AK플라자 홍대점',
#  '그릭데이 홍대점',
#  '갤러리카페바이아스',
#  '꽈페 홍대점',
#  '이스케이퍼스 1호점',
#  '덤앤더머 홍대점',
#  '라포레스타',
#  '디저트머라이언',
#  '로우필름 카페앤갤러리',
#  '퍼즐팩토리 홍대본점',
#  '무제한룸카페',
#  '카페 어싸이드',
#  '할리스 홍대역점',
#  '카페 몽글',
#  '유니크디저트',
#  '써밋 컬쳐 신촌점',
#  '벌툰 홍대본점',
#  '에이스보드카페',
#  '레드버튼 홍대점',
#  '도식화',
#  '리피 메세나폴리스점',
#  '스타벅스 신촌오거리점',
#  '보드놀이터',
#  '스타벅스 홍대역8번출구점',
#  '히트커피로스터스 서교점',
#  '써니네',
#  '홍콩다방 홍대점',
#  '코마이스케이프 홍대점',
#  '공미학 마포홍대점',
#  '스카이래빗',
#  '더지엘',
#  '연남동고양이',
#  '하이준게스트하우스&카페',
#  '달의계단',
#  '미스터리룸이스케이프 홍대점',
#  '위드커피',
#  '카페비비드',
#  '하이타운 서울',
#  '반지하커피',
#  '위밋데얼',
#  '복숭아꽃',
#  '청춘고양이카페 홍대점',
#  '반지캠퍼스카페',
#  '자유인들',
#  '미래안',
#  '러비니돌',
#  '드롭탑 홍대점',
#  '삼다코지',
#  '브라운시티 홍대정문점',
#  '차이 연남점',
#  '헤이쥬드',
#  '카페식스',
#  '시크릿코드 홍대점',
#  '머씨커피',
#  '공차 홍대점',
#  '카페쿠키드',
#  '방탈출 이스케이프하우스',
#  '골든크레마',
#  '재신',
#  '모리셔스브라운 망원점',
#  '커피덕',
#  '커피빈 홍대역8번출구점',
#  '커피와사람들 홍대점',
#  '빵',
#  '고양이다락방 홍대점',
#  '차차티클럽 연남루프탑',
#  '발코니가든',
#  '제로베이스커피',
#  '파우스디멘션',
#  '티와이티디',
#  '메가MGC커피 홍대점',
#  '블로트커피',
#  '소울버튼',
#  '디코더',
#  '커스텀커피 합정점',
#  '마스터키 홍대점',
#  '서교로터리커피바',
#  '엔제리너스 L7홍대점',
#  '고래상점',
#  '티스커피',
#  '크래커',
#  '투썸플레이스 망원역점',
#  '스튜디오B1',
#  '아띠',
#  '이디야커피 홍대중앙점',
#  '하이럽',
#  '카페목수의딸',
#  '랑데자뷰',
#  '투썸플레이스 홍대예술의거리점',
#  '코칭심리카페',
#  '크리미무드',
#  '핸드릭스커피로스터스',
#  '사운드카페 소리',
#  '멍멍벅스',
#  '할리스 홍대역2번출구점',
#  '카페아벨롭',
#  '로스팅마스터즈 본점',
#  '파도',
#  '커피빈 동교동삼거리점',
#  '디비스토리 홍대카페',
#  '이제마스터디클럽 홍대점',
#  '합정 지튼',
#  '손탁커피 본점',
#  '아스트로노머스커피',
#  '오월일일',
#  '산옥커피로스터스',
#  '마오',
#  '매직큐브 홍대직영2호점',
#  '쌔임쌔임',
#  '브라운핸즈 창비',
#  '미카야',
#  '미닝더갤러리',
#  '라드',
#  '더블유오앤',
#  '캔디로그',
#  '카페 바우',
#  '씨네마포',
#  '소셜팩토리 홍대1호점',
#  '지구별방탈출 홍대어드벤처점',
#  '오버트 합정점',
#  '팬스페이스',
#  '맹쿤 2호점',
#  '메가MGC커피 동교점',
#  '보드게임카페 홈즈앤루팡 홍대점',
#  '메가MGC커피 홍대L7점',
#  '멧라운지',
#  '홍익타로',
#  '이디야커피 홍대청기와점',
#  '빽다방 홍대입구점',
#  '이디야커피 합정역점',
#  '카페니타',
#  '카페 이유',
#  '이너커피',
#  '카페 스팟',
#  '오엘커피',
#  '카페페어',
#  '일렉트릭쉽',
#  '춘삼',
#  '룸카페슈가',
#  '투썸플레이스 합정메세나폴리스점',
#  '심신프리 홍대점',
#  '스피키지 방탈출카페',
#  '머더파커 홍대1호점',
#  '달술집',
#  '피아노카페',
#  '깔깔고블린',
#  '커피비 홍대점',
#  '고망고 연남점',
#  '낭만적',
#  '카페어니스티 합정본점',
#  '씨더라이트',
#  '뚜아에모아',
#  '어슬라이스',
#  '퍼스트펭귄카페',
#  '공차 홍대입구역점',
#  '재즈다',
#  '할리스 홍대거리점',
#  '세라젬웰카페 서울합정메세나폴리스직영점',
#  '소마드로잉카페 홍대점',
#  '보마켓 신촌점',
#  '보드팩토리',
#  '컴포즈커피 홍대동교점',
#  '친구네놀이터',
#  '공차 홍대서교점',
#  '투썸플레이스 신촌대로점',
#  '비트포비아 홍대던전3',
#  '크리스가든 홍대',
#  '헤이트먼데이 서교점',
#  '피에스타7',
#  '메가MGC커피 홍대서교점',
#  '드쥬',
#  '오퍼',
#  '요괴냥수비대',
#  '태경사주타로',
#  '카페루치아',
#  '퀘스천마크',
#  '뚜또페르뚜띠',
#  '북카페산책',
#  '수택',
#  '홍대버튼',
#  '슬릿',
#  '유포테이블카페 홍대점',
#  '카페라래',
#  '므농',
#  '트래블카페샬레',
#  '퍼즐팩토리 2호점',
#  '너드플래닛',
#  '오버트서울 합정',
#  '모크',
#  '망고룸카페',
#  '이디야커피 망원역점',
#  '팜플레무스',
#  '작업실01',
#  '타임브릭스',
#  '도카',
#  '구름속에커피집',
#  '두레차',
#  '서교동398',
#  '데블다이스 보드게임카페 홍대점',
#  '프레드앤샐리',
#  '카페345',
#  '홍대 플라',
#  '크로플각',
#  '커피상점이심',
#  '도화서가 홍대점(휴업중)',
#  '익커피 홍대점',
#  '브라운시티카페 상수점',
#  '커피앤스모킹 홍대점',
#  '디저트라팡',
#  '베이브',
#  '프린트카페 합정역점',
#  '콜린스커피',
#  '테이크잇이지 홍대점',
#  '모펀',
#  '퍼스트커피랩 홍대점',
#  '레이크커피바',
#  '커피플라넷',
#  '텀브커피 홍대점',
#  '포비브라이트 홍대점',
#  '게코스리퍼블릭카페',
#  '카페어스',
#  '카페펫크루',
#  '커피벌스데이',
#  '브루브로스커피',
#  '메이드보드게임카페',
#  '쿠나',
#  '포담 티하우스',
#  '해피리틀클럽',
#  '깊이',
#  '코코버블티 홍대입구점',
#  '보노보카페',
#  '로스팅마스터즈 합정점',
#  '치키차카초코 서교본점',
#  '착한커피',
#  '라휘사주카페',
#  '비밀의숲 홍대점',
#  '케이트앤케이크',
#  '로덴드론 동교점',
#  '카페예능',
#  '오렌지페블',
#  '스트레인지프룻',
#  '단편집',
#  '루나틱커피',
#  '카페 팔레트',
#  '카페픽',
#  '카페 SUN',
#  '셉트',
#  '반지만들기카페 홍대점',
#  '아트라우드 하우스 카페&바',
#  '커피랩스로스터리 합정점',
#  '파스쿠찌 메세나폴리스점',
#  '모랩스튜디오',
#  '카페빈',
#  '메가MGC커피 합정중앙점',
#  '레끄레오 보드게임카페',
#  '별숲',
#  '파티셔리마루',
#  '브루클린',
#  '카페웍소베러',
#  '투썸커피 홍대CGV스윗바점',
#  '힐링사주',
#  '빽다방 홍대거리점',
#  '웨이루쿼쿠이 연남본점',
#  '언더플로어',
#  '룸토리',
#  '펀룸카페',
#  '홍콩다방 홍대입구역점',
#  '아지트리',
#  '카페 라스플라미아',
#  '플래시커피 앤 바 홍대점',
#  '딜리커피',
#  '더벤티 홍대점',
#  '카페다카포',
#  '모두다토끼',
#  '카페단',
#  '오디티',
#  '말통커피 합정점',
#  '커피랩',
#  '히든스위치 홍대점',
#  '너프',
#  '슈라즈케이크 서교점',
#  '버티컬',
#  '푸르딩',
#  '래핑포레스트',
#  '비밀의화원 다운타운 홍대점',
#  '담소',
#  '이 마스',
#  '눈내리는숲 설래임 홍대본점',
#  '루프탑지니',
#  '크라임씬카페 코티지가든',
#  '소림커피',
#  '투니크',
#  '오디너리핏 홍대점',
#  '와플칸',
#  '디스코플래닛',
#  '카페코그.',
#  '충무공커피바',
#  '엘리스',
#  '그로잉',
#  '엠북카페',
#  '빽다방 홍대극동방송국점',
#  '라페',
#  '본초당',
#  '노트커피 홍대점',
#  '플레이그라운드',
#  '블루웨일',
#  '핑크스',
#  '카페디에이치',
#  '7080친구라이브',
#  '카페깔깔고블린',
#  '노피디네콩볶는집',
#  '센트24.7 홍대점',
#  '중독',
#  '아올',
#  '벌툰 홍대입구역점',
#  '디저브',
#  '카페COC',
#  '부다페스트카페',
#  '온스커피',
#  '김도윤의사주앤 타로이야기',
#  '노머글 얼라우드',
#  '브런치카페',
#  '카페좋은날',
#  '커먼마치',
#  '바나프레소 합정역점',
#  '훌리건커피',
#  '이디야커피 신촌로터리점',
#  '포레스트엠',
#  '언더크레마',
#  '컴포즈커피 망원역점',
#  'umoae',
#  '디어다온',
#  '에이프릴커피',
#  '레인보우6',
#  '슈퍼보드 홍대점',
#  '문리버',
#  '한땀',
#  '지성화타로',
#  '비온카페',
#  '카페 무아상',
#  '99트레인',
#  '프롬커피바 서교점',
#  '카페엘리',
#  '더루미',
#  '페그로스터스',
#  '언제라도여행',
#  '우니쿠스커피',
#  '카페쿠바노',
#  '오유아이',
#  '카페하울링',
#  '빈즈메이드',
#  '유원지 연남',
#  '데우스 카페 홍대점',
#  '인슈어',
#  '몽마르뜨언덕위']

# %%
#카페 이름과 url 포함된 df만들기 
cafe_seogyodong=pd.DataFrame({"name":names,"url":urls})
cafe_seogyodong
# Out:
#            name                                     url
# 0       피오니 홍대점    https://place.map.kakao.com/26235884
# 1          카페공명  https://place.map.kakao.com/1797970569
# 2      943킹스크로스    https://place.map.kakao.com/53292857
# 3    앤트러사이트 서교점   https://place.map.kakao.com/657926243
# 4     테일러커피 서교점    https://place.map.kakao.com/27248379
# ..          ...                                     ...
# 510       빈즈메이드    https://place.map.kakao.com/90415419
# 511      유원지 연남   https://place.map.kakao.com/442409895
# 512  데우스 카페 홍대점  https://place.map.kakao.com/2013260845
# 513         인슈어  https://place.map.kakao.com/1349448755
# 514     몽마르뜨언덕위    https://place.map.kakao.com/10677996
#
# [515 rows x 2 columns]

# %%
total_seogyodong=pd.DataFrame(columns=["name","review","star","review_num"])

# %%
import tqdm

# %%
for idx,row in tqdm.tqdm_notebook(cafe_seogyodong.iterrows(),total=cafe_seogyodong.shape[0]):
    #위의 코드 합치기. 
    url=row["url"]
    driver.get(url) #링크 접속
    t1=driver.page_source
    t2=BeautifulSoup(t1, "html.parser")
    t3=t2.find(name="div", attrs={"class":"evaluation_review"})
    print("접속 완료")
    driver.implicitly_wait(time_to_wait=5)

    #후기가 없다면 그대로 나가기.
    try:
        review_count=driver.find_element(By.CSS_SELECTOR,"#mArticle > div.cont_essential > div:nth-child(1) > div.place_details > div > div > a:nth-child(3) > span.color_g")
        if review_count.text=="(0)":
            print("후기 없음")
            continue
    except:#후기 미제공
        print("후기 미제공")
        continue
    #리뷰를 끝까지 다 내리기. 
    #중복되는 후기가 너무 많음. =>근데 또 손으로 하나하나 눌러보면 괜찮음. =>implicitly_wait함
    try:
        more_info_button=driver.find_element(By.CSS_SELECTOR,'#mArticle > div.cont_evaluation > div.evaluation_review > a') #더보기 버튼
        while True:
            if more_info_button.get_attribute("class")=='link_more link_unfold':
                break
            driver.execute_script("arguments[0].click();", more_info_button) 
        print("리뷰 내리기 완료")
        #오류: 못 나옴. 해결->css로 버튼에 접근. 
        if more_info_button.get_attribute("class")=='link_more':
            driver.execute_script("arguments[0].click();", more_info_button)
        driver.implicitly_wait(time_to_wait=2)
    except:
        print("내릴 스크롤이 없음. ")
        pass
    try:
        #리뷰 더보기 모두 클릭하기
        long_review_button=driver.find_elements(By.CSS_SELECTOR,'#mArticle > div.cont_evaluation > div.evaluation_review > ul > li > div.comment_info > p > button')

        for button in long_review_button:
            driver.execute_script("arguments[0].click();", button) 
            #개선 사항: 시간이 너무 오래 걸림. 버튼을 한번에 누를 방법이 없을까? 167개 누르는데 1분은 걸린듯. 
        print("리뷰 더보기 모두 클릭 완료")
    except:
        print("누를 더보기 버튼 없음.")
        pass

    #리뷰 모두 끌어오기 
    t1=driver.page_source
    t2=BeautifulSoup(t1, "html.parser")
    t3=t2.find(name="div", attrs={"class":"evaluation_review"})

    print("리뷰 모두 끌어오기 완료 ")


    #별점 리스트 만들기
    star=t3.find_all('span',{'class':'ico_star inner_star'}) #크롤링

    star_list=[]
    for i in star:
        real_star=int(i['style'].split(":")[1].split("%")[0])

        real_star/=20
        star_list.append(real_star)
    #평균 별점 끌어오기<span class="txt_desc">3.6</span>/ 후기 끌어오기
    ave_star=t3.find_all("span",{"class":"txt_desc"})
    ave_star_list=[]
    review_num_list=[]
    index=0
    for i in ave_star:
        if index%2!=0:
            ave_star_list.append(i.text)
        else:
            review_num_list.append(i.text)
        index+=1
    
    
    #리뷰 크롤링
    review=t3.find_all('p',{'class':'txt_comment'})
    #리뷰 리스트 만들기 
    review_list=[]
    for i in review:
        real_review=i.text
        review_list.append(real_review)

    df=pd.DataFrame(columns=["name","review","star"])
    df["review"]=review_list
    df["star"]=star_list
    df["name"]=row["name"]
    df["ave_star"]=ave_star_list
    df["review_num"]=review_num_list
    total_seogyodong=total_seogyodong.append(df,ignore_index=True)
    print("한 가게 리뷰 크롤링 완료")
# Out:
#   0%|          | 0/515 [00:00<?, ?it/s]
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 미제공
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료

# %%
total_seogyodong
# Out:
#           name                                   review  star review_num  \
# 0      피오니 홍대점                            케이크 맛이쑤여..더보기   5.0         13
# 1      피오니 홍대점      케이크가 특별히 엄청 맛있는지는 모르겠어요 평범한 딸케에요더보기   4.0         64
# 2      피오니 홍대점                           케익 4, 커피 2.더보기   3.0        210
# 3      피오니 홍대점                                      더보기   3.0        439
# 4      피오니 홍대점  진쟈 맛있어요.... 사람 많아도 포장 추천 홀케이크 먹고싶다 ㅍ더보기   5.0        215
# ...        ...                                      ...   ...        ...
# 26923  몽마르뜨언덕위                                      더보기   5.0          4
# 26924  몽마르뜨언덕위                  최고에요 집밥 먹고싶으면 갑니다~!!더보기   5.0          2
# 26925  몽마르뜨언덕위                         사장님이 너무 훌륭하신분더보기   5.0          4
# 26926  몽마르뜨언덕위             7000원으로 올랐어요. 맛있고 푸짐해요 !!더보기   5.0         19
# 26927  몽마르뜨언덕위             7000원으로 올랐어요. 맛있고 푸짐해요 !!더보기   5.0         19
#
#       ave_star
# 0          4.7
# 1          4.5
# 2          3.1
# 3          3.6
# 4          4.6
# ...        ...
# 26923      5.0
# 26924      3.0
# 26925      3.0
# 26926      2.4
# 26927      2.4
#
# [26928 rows x 5 columns]

# %%
total_seogyodong.to_csv("total_seogyodong.csv",encoding="utf-8-sig",index=False)
