# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup
import re
import time
import math

#드라이버 불러오기
path = 'chromedriver'
excutable_path = 'chromedriver.exe'
source_url = "https://map.kakao.com/"
driver = webdriver.Chrome(executable_path=excutable_path)

#인터넷 접속
driver.get(source_url)

#서치
search=driver.find_element(By.XPATH,'//*[@id="search.keyword.query"]')
search.send_keys("여의도 카페")
search.send_keys(Keys.ENTER)

driver.implicitly_wait(time_to_wait=5)

# %%
#카페 이름, url 뜯어오기

urls=[]
names=[]


def name_url():
    
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    moreviews = soup.find_all(name="a", attrs={"class":"moreview"}) #상세보기 모두 가져오기. 
    namelist=soup.find_all(name='a',attrs={"class":"link_name"}) #식당 이름 가져오기
    #근데 스크롤 안 내린 거 상에서만 다 가져온 것. 
    # < 눌러서 더 가져와야 함. 
    
    for i in moreviews:
        page_url=i.get("href")
        urls.append(page_url)

    for i in namelist:
        name=i.get("title")
        names.append(name)
    #첫 페이지에서 이름 뜯어옴.

# %%
#첫 페이지에서 가져오기 
name_url()

# %%
#장소 더보기 누르기
more_place_button=driver.find_element(By.XPATH,'//*[@id="info.search.place.more"]')
driver.execute_script("arguments[0].click();", more_place_button)

# %%
page_num=2 #현재 페이지

while True:
    name_url() #현재 페이지에서 다 뜯어오기
    print(page_num)
    page_num+=1 #다음 페이지 번호
    if page_num==6:
        print("> 버튼을 누릅니다.")
        next_button=driver.find_element(By.XPATH,'//*[@id="info.search.page.next"]') #넥스트 버튼 찾기.
        if next_button.get_attribute("class")=='next disabled':
            print("끝났습니다.")
            break
        driver.execute_script("arguments[0].click();", next_button) #넥스트 버튼 누르기
        page_num=1  #페이지 번호 초기화
        print(next_button.get_attribute("class"))
        
    else:
        page_xpath= '//*[@id="info.search.page.no'+str(page_num)+'"]' #다음 페이지의 xpath
        page_button=driver.find_element(By.XPATH,page_xpath) #다음 페이지 버튼 찾기
        driver.execute_script("arguments[0].click();", page_button)  #다음 페이지 버튼 누르기
# Out:
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# next disabled
# 1
# 2
# 3
# 4
# 5
# > 버튼을 누릅니다.
# 끝났습니다.

# %%
names #29페이지부터 제대로 불러와지지 않았음.
# Out:
# ['마호가니커피 여의도점',
#  '더플레이트디저트 더현대서울점',
#  '피그인더가든 여의도점',
#  '홍설',
#  '쓰리버즈 IFC점',
#  '노티드 여의도IFC',
#  '10G',
#  '카페꼼마&얀쿠브레 여의도신영증권점',
#  '아이엠베이글 여의도점',
#  '카페오가닉 여의도본점',
#  '빌리엔젤 여의도삼성생명점',
#  '스타벅스 여의도역R점',
#  '폴바셋 여의도점',
#  '투썸플레이스 여의도점',
#  '스타벅스 여의도점',
#  '서울커피 여의도점',
#  '블루보틀 여의도카페',
#  '스타벅스 여의도IFC점',
#  '패트릭스와플 2호점',
#  '스타벅스 여의도공원R점',
#  '뉴오리진 IFC몰점',
#  '하우스카페',
#  '스타벅스 여의도KBS R점',
#  '스타벅스 동여의도점',
#  '스타벅스 여의도호성점',
#  '올리버브라운 여의도점',
#  '스타벅스 국회의사당역',
#  '카페마마스 여의도점',
#  '투썸플레이스 국회의사당역점',
#  '캐리키즈카페 IFC몰점',
#  '서울커피 여의도점',
#  '블루보틀 여의도카페',
#  '스타벅스 여의도IFC점',
#  '패트릭스와플 2호점',
#  '스타벅스 여의도공원R점',
#  '뉴오리진 IFC몰점',
#  '하우스카페',
#  '스타벅스 여의도KBS R점',
#  '스타벅스 동여의도점',
#  '스타벅스 여의도호성점',
#  '올리버브라운 여의도점',
#  '스타벅스 국회의사당역',
#  '카페마마스 여의도점',
#  '투썸플레이스 국회의사당역점',
#  '캐리키즈카페 IFC몰점',
#  '공차 여의도점',
#  '커피기업',
#  '일리카페 여의도점',
#  '커피앳웍스 여의도점',
#  '커피빈 현대자동차여의도점',
#  '스타벅스 샛강역점',
#  '할리스 여의도파이낸스타워점',
#  '그레이에스프레소',
#  '드롭탑 서여의도점',
#  '폴바셋 여의도국회대로점',
#  '스타벅스 여의도화재보험점',
#  '이디야커피 여의나루역점',
#  '투썸플레이스 여의도파크원점',
#  '스타벅스 여의도IFC몰(L1)R점',
#  '스타벅스 여의도의사당점',
#  '스타벅스 국회대로점',
#  '카페미뇽 여의도점',
#  '투썸플레이스 동여의도점',
#  '카페루고 여의나루점',
#  '평화다방 여의도삼성생명점',
#  '빌리엔젤 서여의도점',
#  '레어마카롱 여의도점',
#  '커피빈 여의도순복음교회옆점',
#  '어펜딕스 여의도본점',
#  '스타벅스 여의도ABL타워점',
#  '스타벅스 롯데캐슬여의도점',
#  '카페 레이어드 더현대서울점',
#  '벨라베네치아',
#  '바이러닉 에스프레소 바 여의도점',
#  '파스쿠찌 여의도KBS본관점',
#  '스타벅스 더현대서울(B2)R점',
#  '시나본 여의도',
#  '스타벅스 여의도일신점',
#  '커피빈 여의도SK증권빌딩점',
#  '투썸플레이스 서여의도점',
#  '파스쿠찌 서여의도점',
#  '엔제리너스 여의도리버타워점',
#  '할리스 여의도하나투자점',
#  '투썸플레이스 여의도롯데캐슬아이비점',
#  '스타벅스 여의도한양증권점',
#  '매머드커피 여의도S점',
#  '남대문커피',
#  '바나프레소 여의도역점',
#  '디저트39 동여의도점',
#  '투썸플레이스 여의도CGV점',
#  '카페마마스 여의도IFC몰점',
#  '헤븐온탑 디스트릭트와이점',
#  '커피빈 여의도교보증권카페점',
#  '곳온니플레이스 여의도점',
#  '커피빈 여의도신영증권별관점',
#  '데이즈커피',
#  '카멜커피 더현대서울점',
#  '여의도커피',
#  '메가MGC커피 여의도역점',
#  '주빈커피 여의도본점',
#  '스타벅스 여의도신한투자증권점',
#  '켄싱턴호텔 여의도 더뷰라운지',
#  '메가MGC커피 서여의도점',
#  '커피소녀',
#  '빽다방 동여의도점',
#  '이디야커피 여의도역점',
#  '카페아에 여의도점',
#  '메가MGC커피 여의도파크원점',
#  '커피볶는집 하드앤빈스',
#  '빽다방 여의도시범상가점',
#  '커피빈 여의도34번지점',
#  '텐퍼센트커피 여의도점',
#  '빽다방 KBS본관점',
#  '할리스 전경련회관점',
#  '시원재',
#  '허니크림',
#  '인하스빈스',
#  '린네스가든',
#  '공차 여의도미원빌딩점',
#  '콩자루',
#  '이디야커피 한국수출입은행점',
#  '컴포즈커피 여의도점',
#  '브루다 여의도역',
#  '플레이인더박스 더현대서울점',
#  '폴바셋 여의도IFC몰점',
#  '하얀과자점',
#  '커피빈 IFC몰2호점',
#  '카페스터닝',
#  '어프로치커피 여의도점',
#  '스윗차징',
#  '파란만잔 여의도점',
#  '커피기업 동여의도점',
#  '이디야커피 국회의사당역점',
#  '에딧76',
#  '이디야커피 KBS별관점',
#  '삼백커피 오륜점',
#  '카페포유',
#  '3노트커피',
#  '스티머스',
#  '이디야커피 서여의도점',
#  '이디야커피 국회대로점',
#  '아마스빈 여의도2호점',
#  '마치커피',
#  '클로리스 더케이타워점',
#  '타이거슈가 여의도IFC몰점',
#  '컴포즈커피 여의도KBS점',
#  '매머드커피 여의도증권가점',
#  '플레이보드카페',
#  '스마일플라워앤카페',
#  '카카오바스켓',
#  '브루다 한국노총',
#  '더벤티 동여의도점',
#  '렐란디',
#  '보훈커피',
#  '홍콩다방 여의도오투테라스점',
#  '컴포즈커피 서여의도점',
#  '63아트 카페',
#  '그라놀로지 여의도IFC점',
#  '타르타르 여의도점',
#  '올댓커피 더현대서울점',
#  '테일러커피 더현대 서울',
#  '커피더캠프 여의도한강캠프점',
#  '커스텀커피 여의도점',
#  '모리셔스브라운 여의도점',
#  '아리스타커피 서여의도점',
#  '슈퍼커피',
#  '골드브라운',
#  '이디야커피 여의도농협재단점',
#  '매스커피 여의도점',
#  '제주스전경련회관점',
#  '젤라또베어',
#  '커피빈 여의도교보증권점',
#  '달콤커피 여의도파크원점',
#  '매머드익스프레스 여의도점',
#  '스위트컵 킁킁커피 국회의사당점',
#  '페어몬트 앰배서더 서울 더 아트리움 라운지',
#  '공차 여의도전경련회관점',
#  '커피코트 동여의도점',
#  '로라스블랑',
#  '달리는커피 서울여의도더현대점',
#  '오가다 서울여의도KBS점',
#  '위너보드카페',
#  '에코브런치',
#  '콘래드서울 플레임즈',
#  '더디퍼커피',
#  '르돌치1946 IFC몰점',
#  '커피기업 여의도파크원점',
#  '삼백커피 신송점',
#  '미켈레커피',
#  '커피사피엔스 미원빌딩점',
#  '네이처셀 여의도캠프',
#  '커피디엔에이로스팅컴퍼니 여의도점',
#  '매머드익스프레스 여의도KBS본관점',
#  '여의숲',
#  '블레드 여의도점',
#  '플랩잭팬트리',
#  '만랩커피 여의도파이낸스타워점',
#  '이디야커피 라이프점',
#  '바나프레소 여의도KBS점',
#  '일리카페IBM점',
#  '컴포즈커피 여의도라이프점',
#  '일리카페 미래에셋증권점',
#  '커피임당',
#  '카페오오디',
#  '커피코트',
#  '카페클라시코 트윈점',
#  '스미스바니',
#  '와인스퀘어',
#  '차향기',
#  '페이브커피 동여의도점',
#  '컴포즈커피 여의도교보증권점',
#  '에스씨커피',
#  '공차 더현대서울점',
#  '북카페서원',
#  '러쉬',
#  '커피빈 IFC몰3호점',
#  '슈퍼커피 63빌딩점',
#  '카페아이엠티 여의도KB금융타워점',
#  '유오디아',
#  '감성커피 서여의도점',
#  '너섬카페',
#  '그럼블커피 여의도1호점',
#  '공차 여의도역사점',
#  '땡스베리루버스카페',
#  '여의도프로틴연구소',
#  '투썸플레이스 여의도광복회관점',
#  '패스트카페 여의도라이프점',
#  'EBS키즈빌',
#  'TAC',
#  '카페베즐리 국민은행여의도전산센터점',
#  '쿠쿠스무스 여의도점',
#  '콘디토리오븐 더현대서울점',
#  '티로프 IFC점',
#  '벤티프레소 여의도점',
#  '빈스투고',
#  '파머스빈 여의도점',
#  '로스팅플래닛',
#  '블루블루엣',
#  '슈퍼말차 더현대서울',
#  '더치랩카페 여의도IFC몰점',
#  '리얼크레마',
#  '아메리칸트레일러 IFC여의도점',
#  '더치앤빈 국회의사당점',
#  '진실롱',
#  '쥬씨 동여의도점',
#  '마랭고',
#  '와필레',
#  '플로리다',
#  '오신나',
#  '도프커피 서여의도점',
#  '매머드익스프레스 여의도라이프점',
#  '아름다운커피 코피아점',
#  '카페드파리 여의도점',
#  '렐란디',
#  '마리나하우스',
#  '매머드익스프레스 여의도역점',
#  '플리퍼스 스탠드 더현대서울점',
#  '카페아이엠티 여의도전경련점',
#  '포션커피',
#  '좋은',
#  '파도커피',
#  '33카페',
#  '플래시커피 여의도 SK증권빌딩점',
#  '로얄호스트커피',
#  '아르켓카페 더현대서울점',
#  'TFT커피로스터스',
#  '워너커피 여의도점',
#  '피규어카페 피카',
#  '포에잇커피',
#  '원바이트',
#  '까페리움',
#  '마치커피 투 고',
#  '가객',
#  '매머드익스프레스 여의도미원빌딩점',
#  '미원커피',
#  '팀커피',
#  '디올바',
#  '커피엔스',
#  '사랑방',
#  '커피온리 서여의도점',
#  '커피퀘스트 서울',
#  '커피베이 여의도순복음교회점',
#  '보헤미안 KBS점',
#  '글로리아진스 커피코리아',
#  '매머드익스프레스 파크원타워1점',
#  '카페소네츠',
#  '브루다 백상빌딩점',
#  '디폴트',
#  '브루클린커피',
#  '박수진전통찻집',
#  '텐퍼센트커피 서여의도점',
#  '구스토',
#  '쥬씨 시범단지점',
#  '라이브하모니카',
#  '커피사이언스',
#  '빈스앤베리즈',
#  '매머드익스프레스 샛강역점',
#  '커피퀘스트',
#  '제주스 여의도역점',
#  '더치앤빈 여의도직영1호점',
#  'T카페 여의도점',
#  '러브섬',
#  '티타임헬씨',
#  '카페바이민',
#  '보이누리',
#  '밀키웨이밀크티 여의도점',
#  '디초콜릿커피 여의도파이낸스점',
#  '빅토리아',
#  '아워홈 국민은행본점',
#  '어거스트커피',
#  '베이스먼트',
#  '카페부에노',
#  '카페꼼마&얀쿠브레 여의도점',
#  '두콩커피',
#  '직장인다방',
#  '켄싱턴호텔 여의도 양츠앤메츠',
#  '오트랑',
#  '블럭플러스',
#  '카페2892',
#  '컬쳐커피',
#  '애플블러썸여의도2호점',
#  '모노치즈',
#  '바디프랜드파크 여의도점',
#  '모노치즈 아일렉스점',
#  '윤중싸롱',
#  '월간커피 국회의사당역점',
#  '티타임',
#  '마이웨이',
#  '힐링포션',
#  '러쉬',
#  '커브사이드',
#  '에그카페24',
#  '더치앤빈 KBS본관점',
#  '일커피 서여의도3호점',
#  '케이팥',
#  '토노커피',
#  '올더타임 여의도점',
#  '존주스',
#  '카페마음',
#  '삼백커피 부국증권점',
#  '생각놀이터하우스',
#  '탬프커피bdg.379',
#  '카페두다트 서여의도점',
#  '스마일카페',
#  '엔레커피 여의도점',
#  '피베테',
#  '모닝해즈 한국피앤지본사점',
#  '앤해피 여의도점',
#  '오가다 서울여의도트윈타워점',
#  '씨씨씨커피',
#  '드라우프',
#  '그리다꿈 여의도이마트점',
#  '헤리티지1919 국회점',
#  '커스토커피 여의도점',
#  '카페로제이',
#  '주식회사 아워레어 여의도1호점',
#  '웰가커피',
#  '원빈',
#  '클로리스 IFC몰점',
#  '하루',
#  '풍경',
#  '피아제',
#  '더주스박스',
#  '카페쿠바 국회의사당역점',
#  '저스트',
#  '그릭나인',
#  '카페콩냥',
#  '아름다온 여의도지점',
#  '아이엔씨풀서비스 카페말로 여의도점',
#  '카페소프트 하이투자증권점',
#  '에스프레소랩(EspressoLab)',
#  '데이비드쥬스 여의도점',
#  '카페트리니티',
#  '더카페엔 여의도백화점점',
#  '바리스타희',
#  '샤인',
#  '궁',
#  '크레이지커피앤프룻',
#  '커피블랙83도',
#  '밑업(meetup)',
#  '카페레브',
#  '카페믹스',
#  '브루테크네커피',
#  '르솔레일(LESOLEIL)',
#  '더카페 여의도백화점점',
#  '칠분의오커피',
#  '군바리스타 여의도점',
#  '지유명차 여의도점',
#  '롤피',
#  '커피콩',
#  '스몰굿커피 여의도점',
#  '커피온리 샛강역사점',
#  '마얘 더현대서울',
#  '다정다감',
#  '커피집단 커피소프트',
#  '봄여름가을겨울',
#  '블랙카페편의점',
#  '더착한커피플러스',
#  '팔공티 국회의사당역점',
#  '웻즐스프레즐',
#  '더치랩 여의도점',
#  '카페컴온 여의도부국증권점',
#  '커프카페',
#  '기다리다',
#  '킹조지',
#  '카페초콜릿',
#  '제이엔제이커피',
#  '불커피 여의도점',
#  '이랜드파크외식 여의나루',
#  '카페오디디',
#  '9카페',
#  '카페빈스',
#  'Cafe the Classic',
#  '카페 티박스',
#  '포코아포코',
#  '재잘재잘',
#  '큰형커피',
#  '샤부르 여의도점',
#  '전통찻집',
#  '엑소세',
#  '카페컴온 여의도점',
#  '굿플랜물산',
#  '매머드익스프레스 여의도IFC몰',
#  '와우',
#  '담소',
#  '모노레일',
#  '베가',
#  '차얌 여의도시범단지점',
#  '데이즈앤하하코',
#  '커피볶는집',
#  '라운지리포즈',
#  '커피사피엔스 여의도미원빌딩',
#  '브라운아이스',
#  '힐링',
#  '한주면옥',
#  '그냥',
#  '카페쉐어링 휴렛팩커드점',
#  '러브트리',
#  '낑하',
#  '펩코코리아(주)',
#  '메종드마리안느여의도',
#  '트웬티포세븐',
#  '프로포즈유',
#  '버틀러커피',
#  '구디구디',
#  '에잇비돌체 국회의사당역점',
#  '도민까페',
#  '모노레일에스프레소 여의도점',
#  '아리스타 서여의도점',
#  '어니스티',
#  '태영매니지먼트',
#  '끌로에',
#  '유한책임회사 뉴프론티어그룹',
#  '33카페',
#  '파도커피',
#  '팀커피',
#  '그리다꿈 여의도샛강점',
#  '한입',
#  '라콤커피',
#  '슈퍼커피 여의도역점',
#  '클럽피쉬',
#  '커피스테이션',
#  '포에잇커피',
#  '아미고',
#  '브루테크네',
#  '새싹커피',
#  '칼딘커피 여의도점',
#  '올리브',
#  '바벨',
#  'HOOTAC',
#  '카페에스파니 서여의도점',
#  '그냥',
#  '커피혁명',
#  '크로플스토리',
#  '씨앤아이',
#  '포프트커피',
#  '카페길',
#  '브루클린커피',
#  '이디야커피 대방역점',
#  '트리플A커피 대방점',
#  '레어그루브',
#  '이디야커피 노량진드림스퀘어점',
#  '매머드익스프레스 대방역점',
#  '르플뢰브',
#  '꾸밍',
#  '투썸플레이스 대방역점',
#  '스타벅스 노량진역점',
#  '채그로카페',
#  '밍구네다방',
#  '미쁘다',
#  '히코코 노량진수산시장점',
#  '투썸플레이스',
#  '달콤쌉싸롱',
#  '카페오버데어',
#  '로그아웃(LOGOUT)',
#  '커피에반하다 대방점',
#  '카페엘마르코',
#  '단골커피',
#  '커피팩토리쏘 교육점',
#  '뜨랑블랑',
#  '오슬로우 노량진점',
#  '커피팩토리쏘 공장점',
#  '이디야커피 신길역점',
#  '이디야커피 노량진CTS점',
#  '오월이구',
#  '도로도로커피숍 노량진점',
#  '스위트 디',
#  '스윗드오',
#  '모카',
#  '트립티',
#  '커피크레이브 대방역점',
#  '매머드익스프레스 노량진큐브점',
#  '카페 드 리브',
#  '마음마루',
#  '설빙 노량진점']

# %%
#카페 리스트 만들기 
cafe_df_3=pd.DataFrame({"name":names,"url":urls})
cafe_df_3
# Out:
#                 name                                     url
# 0        마호가니커피 여의도점   https://place.map.kakao.com/409589446
# 1    더플레이트디저트 더현대서울점  https://place.map.kakao.com/2122184252
# 2        피그인더가든 여의도점  https://place.map.kakao.com/1149136625
# 3                 홍설    https://place.map.kakao.com/23753282
# 4          쓰리버즈 IFC점   https://place.map.kakao.com/153151026
# ..               ...                                     ...
# 510      커피크레이브 대방역점  https://place.map.kakao.com/1629160308
# 511  매머드익스프레스 노량진큐브점  https://place.map.kakao.com/1190586547
# 512          카페 드 리브   https://place.map.kakao.com/989233886
# 513             마음마루   https://place.map.kakao.com/346556088
# 514          설빙 노량진점    https://place.map.kakao.com/24875726
#
# [515 rows x 2 columns]

# %%
cafe_df_3.to_csv("cafe_df_3.csv",index=False, encoding="cp949")

# %%
total_review=pd.DataFrame(columns=["name","review","star","review_num"]) #전체 리뷰 저장할 데이터 프레임.

# %%
#cafe 이름 불러오기
cafe_df_3=pd.read_csv("cafe_df_3.csv",encoding="cp949")
cafe_df_3.head()
# Out:
#               name                                     url
# 0      마호가니커피 여의도점   https://place.map.kakao.com/409589446
# 1  더플레이트디저트 더현대서울점  https://place.map.kakao.com/2122184252
# 2      피그인더가든 여의도점  https://place.map.kakao.com/1149136625
# 3               홍설    https://place.map.kakao.com/23753282
# 4        쓰리버즈 IFC점   https://place.map.kakao.com/153151026

# %%
import tqdm

# %%
for idx,row in tqdm.tqdm_notebook(cafe_df_3.iterrows(),total=cafe_df_3.shape[0]):
    #위의 코드 합치기. 
    url=row["url"]
    driver.get(url) #링크 접속
    t1=driver.page_source
    t2=BeautifulSoup(t1, "html.parser")
    t3=t2.find(name="div", attrs={"class":"evaluation_review"})
    print("접속 완료")
    driver.implicitly_wait(time_to_wait=5)

    #후기가 없다면 그대로 나가기.
    try:
        review_count=driver.find_element(By.CSS_SELECTOR,"#mArticle > div.cont_essential > div:nth-child(1) > div.place_details > div > div > a:nth-child(3) > span.color_g")
        if review_count.text=="(0)":
            print("후기 없음")
            continue
    except:#후기 미제공
        print("후기 미제공")
        continue
    #리뷰를 끝까지 다 내리기. 
    #중복되는 후기가 너무 많음. =>근데 또 손으로 하나하나 눌러보면 괜찮음. =>implicitly_wait함
    try:
        more_info_button=driver.find_element(By.CSS_SELECTOR,'#mArticle > div.cont_evaluation > div.evaluation_review > a') #더보기 버튼
        while True:
            if more_info_button.get_attribute("class")=='link_more link_unfold':
                break
            driver.execute_script("arguments[0].click();", more_info_button) 
        print("리뷰 내리기 완료")
        #오류: 못 나옴. 해결->css로 버튼에 접근. 
        if more_info_button.get_attribute("class")=='link_more':
            driver.execute_script("arguments[0].click();", more_info_button)
        driver.implicitly_wait(time_to_wait=2)
    except:
        print("내릴 스크롤이 없음. ")
        pass
    try:
        #리뷰 더보기 모두 클릭하기
        long_review_button=driver.find_elements(By.CSS_SELECTOR,'#mArticle > div.cont_evaluation > div.evaluation_review > ul > li > div.comment_info > p > button')

        for button in long_review_button:
            driver.execute_script("arguments[0].click();", button) 
            #개선 사항: 시간이 너무 오래 걸림. 버튼을 한번에 누를 방법이 없을까? 167개 누르는데 1분은 걸린듯. 
        print("리뷰 더보기 모두 클릭 완료")
    except:
        print("누를 더보기 버튼 없음.")
        pass

    #리뷰 모두 끌어오기 
    t1=driver.page_source
    t2=BeautifulSoup(t1, "html.parser")
    t3=t2.find(name="div", attrs={"class":"evaluation_review"})

    print("리뷰 모두 끌어오기 완료 ")


    #별점 리스트 만들기
    star=t3.find_all('span',{'class':'ico_star inner_star'}) #크롤링

    star_list=[]
    for i in star:
        real_star=int(i['style'].split(":")[1].split("%")[0])

        real_star/=20
        star_list.append(real_star)
    #평균 별점 끌어오기<span class="txt_desc">3.6</span>/ 후기 끌어오기
    ave_star=t3.find_all("span",{"class":"txt_desc"})
    ave_star_list=[]
    review_num_list=[]
    index=0
    for i in ave_star:
        if index%2!=0:
            ave_star_list.append(i.text)
        else:
            review_num_list.append(i.text)
        index+=1
    
    
    #리뷰 크롤링
    review=t3.find_all('p',{'class':'txt_comment'})
    #리뷰 리스트 만들기 
    review_list=[]
    for i in review:
        real_review=i.text
        review_list.append(real_review)

    df=pd.DataFrame(columns=["name","review","star"])
    df["review"]=review_list
    df["star"]=star_list
    df["name"]=row["name"]
    df["ave_star"]=ave_star_list
    df["review_num"]=review_num_list
    total_review=total_review.append(df,ignore_index=True)
    print("한 가게 리뷰 크롤링 완료")
# Out:
#   0%|          | 0/515 [00:00<?, ?it/s]
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 미제공
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 내릴 스크롤이 없음.
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료
# 접속 완료
# 후기 없음
# 접속 완료
# 리뷰 내리기 완료
# 리뷰 더보기 모두 클릭 완료
# 리뷰 모두 끌어오기 완료
# 한 가게 리뷰 크롤링 완료

# %%
total_review
# Out:
#              name                                             review star  \
# 0     마호가니커피 여의도점  밤고구마 티라미수 때문에 재방문하고 싶은 곳어디에서도 먹어보지 못한 맛이다크림라떼는...  5.0
# 1     마호가니커피 여의도점                                                더보기  3.0
# 2     마호가니커피 여의도점                                                더보기  3.0
# 3     마호가니커피 여의도점                                                더보기  3.0
# 4     마호가니커피 여의도점               사람 구경하면서 커피먹었음 ㅎㅎ 저는 개인적으로 좋았어요 ~더보기  4.0
# ...           ...                                                ...  ...
# 9798      설빙 노량진점  노량진점 설빙 진짜별로네요 최악이에요 고객한테 대하는 전화 말투법이 상당히 거칠고 ...  1.0
# 9799      설빙 노량진점                      배달 시켰는데 다른 지점보다 양이 많아서 놀람.더보기  5.0
# 9800      설빙 노량진점                       맛잇음 다른 설빙 가게들보다 양도 많은거 같고더보기  4.0
# 9801      설빙 노량진점  체육관 2개와 포켓스탑 1개 잡힘.영등포 설빙은 시설도 빙수 퀄리티도  최악인데 여...  4.0
# 9802      설빙 노량진점  학생들을 위한 배려인건지는 모르겠으나 설빙 다른 지점보다 토핑이나 재료를 후하게 얹...  4.0
#
#      review_num ave_star
# 0            70      4.1
# 1           295      3.1
# 2            97      3.9
# 3             6      3.5
# 4            87      4.7
# ...         ...      ...
# 9798          2      1.0
# 9799         29      4.2
# 9800         10      1.9
# 9801        318      3.4
# 9802         26      3.3
#
# [9803 rows x 5 columns]

# %%
total_review.to_csv("total_review_여의도.csv",encoding="utf-8-sig" ,index=False) #이모지도 제대로 나오고! 오류 해결!

# %%
#review에 더보기만 나온 경우: 별점만 있는 리뷰. 삭제하면 될듯.
